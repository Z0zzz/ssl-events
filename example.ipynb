# %%
import uproot

# %%
file = uproot.open("fcc/small_gun_sample/out_reco_edm4hep_REC.edm4hep.root")
file.keys()
# Out:
# ['events;4',
#  'events;3',
#  'configuration_metadata;1',
#  'metadata;1',
#  'podio_metadata;1']

# %%
root_events = file["events"]
root_events.keys()
# Out:
# ['BuildUpVertices',
#  'BuildUpVertices/BuildUpVertices.type',
#  'BuildUpVertices/BuildUpVertices.chi2',
#  'BuildUpVertices/BuildUpVertices.ndf',
#  'BuildUpVertices/BuildUpVertices.position.x',
#  'BuildUpVertices/BuildUpVertices.position.y',
#  'BuildUpVertices/BuildUpVertices.position.z',
#  'BuildUpVertices/BuildUpVertices.covMatrix.values[6]',
#  'BuildUpVertices/BuildUpVertices.algorithmType',
#  'BuildUpVertices/BuildUpVertices.parameters_begin',
#  'BuildUpVertices/BuildUpVertices.parameters_end',
#  'BuildUpVertices/BuildUpVertices.particles_begin',
#  'BuildUpVertices/BuildUpVertices.particles_end',
#  '_BuildUpVertices_particles',
#  '_BuildUpVertices_particles/_BuildUpVertices_particles.index',
#  '_BuildUpVertices_particles/_BuildUpVertices_particles.collectionID',
#  '_BuildUpVertices_parameters',
#  'BuildUpVertices_associatedParticles',
#  'BuildUpVertices_associatedParticles/BuildUpVertices_associatedParticles.weight',
#  '_BuildUpVertices_associatedParticles_to',
# ...

# %%
file.get("podio_metadata")
# Out:
# <TTree 'podio_metadata' (9 branches) at 0x000105ad7810>

# %%
from postprocessing import process_one_file
from utils_edm import generate_examples
import os

out_directory = "fcc_processed/"

os.makedirs(out_directory, exist_ok=True)

fi = "fcc/small_gun_sample/out_reco_edm4hep_REC.edm4hep.root"
fo = out_directory+"out_reco_edm4hep_REC.parquet"

out = process_one_file(fi, fo, "fcc")
# Out:
# loading fcc/small_gun_sample/out_reco_edm4hep_REC.edm4hep.root
#   2%|▏         | 2/100 [00:00<00:12,  8.13it/s]
# track features:  9
# gp_to_track:  (11, 9)
# gp_to_cluster:  (11, 14)
# number of gps:  11
# ###
# gen_features_new:  (11,)
# X_track:  (9, 16)
# track features:  5
# gp_to_track:  (14, 5)
# gp_to_cluster:  (14, 16)
# number of gps:  14
# ###
# gen_features_new:  (14,)
# X_track:  (5, 16)
# track features:  7
#   4%|▍         | 4/100 [00:00<00:11,  8.15it/s]
# gp_to_track:  (9, 7)
# gp_to_cluster:  (9, 10)
# number of gps:  9
# ###
# gen_features_new:  (9,)
# X_track:  (7, 16)
# track features:  8
# gp_to_track:  (10, 8)
# gp_to_cluster:  (10, 11)
# number of gps:  10
# ###
# gen_features_new:  (10,)
# X_track:  (8, 16)
#   5%|▌         | 5/100 [00:00<00:11,  7.95it/s]
# track features:  10
# gp_to_track:  (15, 10)
# gp_to_cluster:  (15, 17)
# number of gps:  15
# ###
# gen_features_new:  (15,)
# X_track:  (10, 16)
# track features:  6
# gp_to_track:  (9, 6)
# ...

# %%
gen = generate_examples(["fcc_processed/out_reco_edm4hep_REC.parquet",])

# %%
data = next(gen)[1]

# %%
data.keys()
# Out:
# dict_keys(['X', 'ytarget', 'ycand', 'genmet', 'gen_track_assoc_mats', 'gen_cluster_assoc_mats'])

# %%
print(data["X"].shape)
print(data["gen_track_assoc_mats"].shape)
print(data["gen_cluster_assoc_mats"].shape)
print(data["ytarget"].shape)
print(data["ycand"].shape)
print(data["genmet"])
# Out:
# (23, 17)
# (11, 9)
# (11, 14)
# (23, 13)
# (23, 13)
# 47.566840476630354

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.imshow(data["gen_track_assoc_mats"], cmap='gray_r')
plt.colorbar()
plt.title('gen particle - track association matrix')
plt.ylabel('gen particle')
plt.xlabel('track associated')
plt.show()

# %%
plt.imshow(data["gen_cluster_assoc_mats"], cmap='gray_r')
plt.colorbar()
plt.title('gen particle - cluster association matrix')
plt.ylabel('gen particle')
plt.xlabel('cluster associated')
plt.show()
